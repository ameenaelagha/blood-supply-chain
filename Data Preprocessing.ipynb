# %%
import gurobipy as gp
from gurobipy import GRB
import pandas as pd
import numpy as np
import googlemaps

np.random.seed(1)

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## Geocoding

# %%
key = ""
gmaps = googlemaps.Client(key=key)

# %% [markdown]
# ### Malaysia hospital data

# %%
hospital_df = pd.read_csv("Data Files/Hospital Locations.csv", usecols=["Hospital", "Area"])
hospital_df
# Out:
#                                        Hospital        Area
# 0         Hospital Pakar Sultanah Fatimah, Muar       Johor
# 1     Hospital Sultanah Nora Ismail, Batu Pahat       Johor
# 2    Hospital Enche Besar Hajjah Kalsom, Kluang       Johor
# 3                              Hospital Segamat       Johor
# 4                              Hospital Pontian       Johor
# ..                                          ...         ...
# 145                             Hospital Dungun  Terengganu
# 146                            Hospital Kemaman  Terengganu
# 147                              Hospital Besut  Terengganu
# 148                    Hospital Hulu Terengganu  Terengganu
# 149                              Hospital Setiu  Terengganu
#
# [150 rows x 2 columns]

# %% [markdown]
# Removing duplicate hospitals

# %%
hospital_df = hospital_df.drop_duplicates("Hospital").reset_index(drop=True)
hospital_df
# Out:
#                                        Hospital        Area
# 0         Hospital Pakar Sultanah Fatimah, Muar       Johor
# 1     Hospital Sultanah Nora Ismail, Batu Pahat       Johor
# 2    Hospital Enche Besar Hajjah Kalsom, Kluang       Johor
# 3                              Hospital Segamat       Johor
# 4                              Hospital Pontian       Johor
# ..                                          ...         ...
# 144                             Hospital Dungun  Terengganu
# 145                            Hospital Kemaman  Terengganu
# 146                              Hospital Besut  Terengganu
# 147                    Hospital Hulu Terengganu  Terengganu
# 148                              Hospital Setiu  Terengganu
#
# [149 rows x 2 columns]

# %%
hospital_df["address"] = hospital_df["Hospital"] + ", " + hospital_df["Area"] + ", Malaysia"

# %% [markdown]
# ### Geocoding hospitals

# %%
def get_geocode(address):
    geo_result = gmaps.geocode(address)
    
    # Extracting latitude and longitude from the response json
    lat = geo_result[0]["geometry"]["location"]["lat"]
    lng = geo_result[0]["geometry"]["location"]["lng"]
    
    return lat, lng

# %%
hospital_df[["lat","lng"]] = hospital_df.apply(lambda row: get_geocode(row.address), axis='columns', result_type='expand')
hospital_df
# Out:
#                                        Hospital        Area
# 0         Hospital Pakar Sultanah Fatimah, Muar       Johor  \
# 1     Hospital Sultanah Nora Ismail, Batu Pahat       Johor
# 2    Hospital Enche Besar Hajjah Kalsom, Kluang       Johor
# 3                              Hospital Segamat       Johor
# 4                              Hospital Pontian       Johor
# ..                                          ...         ...
# 144                             Hospital Dungun  Terengganu
# 145                            Hospital Kemaman  Terengganu
# 146                              Hospital Besut  Terengganu
# 147                    Hospital Hulu Terengganu  Terengganu
# 148                              Hospital Setiu  Terengganu
#
#                                                address       lat         lng
# 0    Hospital Pakar Sultanah Fatimah, Muar, Johor, ...  2.057115  102.574446
# 1    Hospital Sultanah Nora Ismail, Batu Pahat, Joh...  1.837516  102.940997
# 2    Hospital Enche Besar Hajjah Kalsom, Kluang, Jo...  2.038227  103.311296
# 3                    Hospital Segamat, Johor, Malaysia  2.493269  102.859063
# 4                    Hospital Pontian, Johor, Malaysia  1.498460  103.385207
# ..                                                 ...       ...         ...
# 144              Hospital Dungun, Terengganu, Malaysia  4.751876  103.414832
# 145             Hospital Kemaman, Terengganu, Malaysia  4.232613  103.421057
# 146               Hospital Besut, Terengganu, Malaysia  5.729650  102.492570
# 147     Hospital Hulu Terengganu, Terengganu, Malaysia  5.073216  103.044775
# 148               Hospital Setiu, Terengganu, Malaysia  5.514127  102.769517
#
# [149 rows x 5 columns]

# %% [markdown]
# Removing some hospitals that are not connected to any blood centers (via Google Maps driving routes)

# %%
hospital_df[hospital_df.Hospital == "Langkawi Hospital"]
# Out:
#              Hospital   Area
# 17  Langkawi Hospital  Kedah

# %%
hospital_df[hospital_df.Hospital == "Hospital Angkatan Tentera, Pangkalan TLDM, Lumut"]
# Out:
#                                             Hospital   Area
# 84  Hospital Angkatan Tentera, Pangkalan TLDM, Lumut  Perak

# %%
hospital_df = hospital_df.drop([17, 84], axis = 0).reset_index(drop=True)
hospital_df
# Out:
#                                        Hospital        Area
# 0         Hospital Pakar Sultanah Fatimah, Muar       Johor
# 1     Hospital Sultanah Nora Ismail, Batu Pahat       Johor
# 2    Hospital Enche Besar Hajjah Kalsom, Kluang       Johor
# 3                              Hospital Segamat       Johor
# 4                              Hospital Pontian       Johor
# ..                                          ...         ...
# 142                             Hospital Dungun  Terengganu
# 143                            Hospital Kemaman  Terengganu
# 144                              Hospital Besut  Terengganu
# 145                    Hospital Hulu Terengganu  Terengganu
# 146                              Hospital Setiu  Terengganu
#
# [147 rows x 2 columns]

# %%
hospital_df.to_csv("Hospital Locations.csv", index=False)

# %% [markdown]
# ### Geocoding blood centers

# %%
b_centers = ['Hospital Duchess Of Kent', 'Hospital Melaka', 'Hospital Miri',
             'Hospital Pulau Pinang', 'Hospital Queen Elizabeth II',
             'Hospital Raja Perempuan Zainab II',
             'Hospital Raja Permaisuri Bainun', 'Hospital Seberang Jaya',
             'Hospital Seri Manjung', 'Hospital Sibu',
             'Hospital Sultan Haji Ahmad Shah', 'Hospital Sultanah Aminah',
             'Hospital Sultanah Bahiyah', 'Hospital Sultanah Nora Ismail',
             'Hospital Sultanah Nur Zahirah', 'Hospital Taiping',
             'Hospital Tawau', 'Hospital Tengku Ampuan Afzan',
             'Hospital Tengku Ampuan Rahimah', 'Hospital Tuanku Jaafar',
             'Hospital Umum Sarawak', 'Pusat Darah Negara']

# %%
bc_df = pd.DataFrame({"Name": b_centers})
bc_df
# Out:
#                                  Name
# 0            Hospital Duchess Of Kent
# 1                     Hospital Melaka
# 2                       Hospital Miri
# 3               Hospital Pulau Pinang
# 4         Hospital Queen Elizabeth II
# 5   Hospital Raja Perempuan Zainab II
# 6     Hospital Raja Permaisuri Bainun
# 7              Hospital Seberang Jaya
# 8               Hospital Seri Manjung
# 9                       Hospital Sibu
# 10    Hospital Sultan Haji Ahmad Shah
# 11           Hospital Sultanah Aminah
# 12          Hospital Sultanah Bahiyah
# 13      Hospital Sultanah Nora Ismail
# 14      Hospital Sultanah Nur Zahirah
# 15                   Hospital Taiping
# 16                     Hospital Tawau
# 17       Hospital Tengku Ampuan Afzan
# 18     Hospital Tengku Ampuan Rahimah
# 19             Hospital Tuanku Jaafar
# 20              Hospital Umum Sarawak
# 21                 Pusat Darah Negara

# %%
bc_df["address"] = bc_df["Name"] + ", Malaysia"

# %%
bc_df[["lat","lng"]] = bc_df.apply(lambda row: get_geocode(row.address), axis='columns', result_type='expand')

# %%
bc_df.to_csv("Blood Center Locations.csv", index=False)

# %% [markdown]
# ## Travel time between centers

# %%
hospital_df = pd.read_csv("Data Files/Hospital Locations.csv")
bc_df = pd.read_csv("Data Files/Blood Center Locations.csv")

# %%
hospital_df["coords"] = list(zip(hospital_df["lat"], hospital_df["lng"]))
bc_df["coords"] = list(zip(bc_df["lat"], bc_df["lng"]))

# %%
n_centers = 22
max_elements = 100 # GMaps API has a limit of 100 elements per call
max_dists = int(max_elements/n_centers)
time_df = pd.DataFrame(index=b_centers)

for i in range(0, len(hospital_df), max_dists):
    res = gmaps.distance_matrix(origins=bc_df["coords"],
                                destinations=hospital_df.loc[i:i+max_dists - 1, "coords"],
                                mode="driving")

    rows = []
    for row in res["rows"]:
        rows.append(pd.json_normalize(row["elements"])["duration.value"].values)
        
    new_hospital_df = pd.DataFrame(rows, 
                          index = b_centers,
                          columns = [hospital_df.loc[x, "Hospital"] for x in range(i, min(len(hospital_df), i+max_dists))])

    # Cocatenating the additional distances with the original distance matrix
    time__df = pd.concat([time_df, new_hospital_df], axis = 1)

# %%
time_df = round(time_df/60)

# %%
time_df.head()
# Out:
#                              Hospital Pakar Sultanah Fatimah, Muar
# Hospital Duchess Of Kent                                    6453.0  \
# Hospital Melaka                                               51.0
# Hospital Miri                                               5676.0
# Hospital Pulau Pinang                                        365.0
# Hospital Queen Elizabeth II                                 6080.0
#
#                              Hospital Sultanah Nora Ismail, Batu Pahat
# Hospital Duchess Of Kent                                        6432.0  \
# Hospital Melaka                                                  117.0
# Hospital Miri                                                   5655.0
# Hospital Pulau Pinang                                            413.0
# Hospital Queen Elizabeth II                                     6059.0
#
#                              Hospital Enche Besar Hajjah Kalsom, Kluang
# Hospital Duchess Of Kent                                         6414.0  \
# Hospital Melaka                                                   115.0
# Hospital Miri                                                    5637.0
# Hospital Pulau Pinang                                             411.0
# Hospital Queen Elizabeth II                                      6041.0
#
#                              Hospital Segamat  Hospital Pontian
# Hospital Duchess Of Kent               6462.0            6375.0  \
# Hospital Melaka                         107.0             142.0
# Hospital Miri                          5685.0            5598.0
# Hospital Pulau Pinang                   403.0             438.0
# Hospital Queen Elizabeth II            6089.0            6002.0
#
#                              Hospital Kota Tinggi  Hospital Mersing
# Hospital Duchess Of Kent                   6376.0            6449.0  \
# Hospital Melaka                             173.0             195.0
# Hospital Miri                              5599.0            5672.0
# Hospital Pulau Pinang                       469.0             491.0
# Hospital Queen Elizabeth II                6003.0            6076.0
#
#                              Hospital Tangkak
# Hospital Duchess Of Kent               6448.0  \
# Hospital Melaka                          48.0
# Hospital Miri                          5672.0
# Hospital Pulau Pinang                   344.0
# Hospital Queen Elizabeth II            6076.0
#
#                              Hospital Temenggung Seri Maharaja Tun Ibrahim, Kulai
# Hospital Duchess Of Kent                                                6359.0     \
# Hospital Melaka                                                          137.0
# Hospital Miri                                                           5583.0
# Hospital Pulau Pinang                                                    434.0
# Hospital Queen Elizabeth II                                             5987.0
#
#                              Sultan Ismail Hospital  ...
# Hospital Duchess Of Kent                     6352.0  ...  \
# Hospital Melaka                               150.0  ...
# Hospital Miri                                5575.0  ...
# Hospital Pulau Pinang                         446.0  ...
# Hospital Queen Elizabeth II                  5979.0  ...
#
#                              Hospital Tengku Ampuan Jemaah, Sabak Bernam
# Hospital Duchess Of Kent                                          6643.0  \
# Hospital Melaka                                                    210.0
# Hospital Miri                                                     5866.0
# Hospital Pulau Pinang                                              194.0
# Hospital Queen Elizabeth II                                       6270.0
#
#                              Hospital Tengku Ampuan Rahimah, Klang
# Hospital Duchess Of Kent                                    6557.0  \
# Hospital Melaka                                              124.0
# Hospital Miri                                               5780.0
# Hospital Pulau Pinang                                        254.0
# Hospital Queen Elizabeth II                                 6184.0
#
#                              Universiti Putra Malaysia Teaching Hospital
# Hospital Duchess Of Kent                                          6529.0  \
# Hospital Melaka                                                     96.0
# Hospital Miri                                                     5752.0
# Hospital Pulau Pinang                                              261.0
# Hospital Queen Elizabeth II                                       6156.0
#
#                              Universiti Teknologi MARA Teaching Hospital, Puncak Alam
# Hospital Duchess Of Kent                                                6562.0         \
# Hospital Melaka                                                          129.0
# Hospital Miri                                                           5785.0
# Hospital Pulau Pinang                                                    238.0
# Hospital Queen Elizabeth II                                             6189.0
#
#                              Hospital Sultanah Nur Zahirah, Kuala Terengganu
# Hospital Duchess Of Kent                                              6730.0  \
# Hospital Melaka                                                        364.0
# Hospital Miri                                                         5953.0
# Hospital Pulau Pinang                                                  426.0
# Hospital Queen Elizabeth II                                           6357.0
#
#                              Hospital Dungun  Hospital Kemaman
# Hospital Duchess Of Kent              6677.0            6644.0  \
# Hospital Melaka                        310.0             278.0
# Hospital Miri                         5900.0            5867.0
# Hospital Pulau Pinang                  458.0             425.0
# Hospital Queen Elizabeth II           6304.0            6271.0
#
#                              Hospital Besut  Hospital Hulu Terengganu
# Hospital Duchess Of Kent             6786.0                    6696.0  \
# Hospital Melaka                       420.0                     330.0
# Hospital Miri                        6010.0                    5920.0
# Hospital Pulau Pinang                 326.0                     431.0
# Hospital Queen Elizabeth II          6414.0                    6324.0
#
#                              Hospital Setiu
# Hospital Duchess Of Kent             6746.0
# Hospital Melaka                       380.0
# Hospital Miri                        5969.0
# Hospital Pulau Pinang                 365.0
# Hospital Queen Elizabeth II          6373.0
#
# [5 rows x 149 columns]

# %%
time_df.drop("Langkawi Hospital", axis=1, inplace=True)

# %%
time_df.drop("Hospital Angkatan Tentera, Pangkalan TLDM, Lumut", axis=1, inplace=True)

# %%
time_df.to_csv("Data Files/Travel Times.csv")
